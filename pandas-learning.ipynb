# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2026-05-17   -0.169712
# 2026-05-18   -1.006015
# 2026-05-19    0.035245
# 2026-05-20   -1.343448
# 2026-05-21    3.472495
# 2026-05-22   -0.476399
# Freq: D, Name: A, dtype: float64

# %%
df[["B","A"]]
# Out:
#                    B         A
# 2026-05-17 -0.414671 -0.169712
# 2026-05-18 -0.013800 -1.006015
# 2026-05-19 -0.943528  0.035245
# 2026-05-20 -0.767639 -1.343448
# 2026-05-21  0.354432  3.472495
# 2026-05-22  1.307388 -0.476399

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2026-05-17 -0.169712 -0.414671 -1.146815 -0.842660
# 2026-05-18 -1.006015 -0.013800 -1.739034  0.081955
# 2026-05-19  0.035245 -0.943528 -0.436862 -1.182899

# %%
df["20260517":"20260519"]
# Out:
#                    A         B         C         D
# 2026-05-17 -0.169712 -0.414671 -1.146815 -0.842660
# 2026-05-18 -1.006015 -0.013800 -1.739034  0.081955
# 2026-05-19  0.035245 -0.943528 -0.436862 -1.182899

# %%
df.loc[dates[0]]
# Out:
# A   -0.169712
# B   -0.414671
# C   -1.146815
# D   -0.842660
# Name: 2026-05-17 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2026-05-17 -0.169712 -0.414671
# 2026-05-18 -1.006015 -0.013800
# 2026-05-19  0.035245 -0.943528
# 2026-05-20 -1.343448 -0.767639
# 2026-05-21  3.472495  0.354432
# 2026-05-22 -0.476399  1.307388

# %%
df.loc["20260517":"20260519", ["A", "B"]]
# Out:
#                    A         B
# 2026-05-17 -0.169712 -0.414671
# 2026-05-18 -1.006015 -0.013800
# 2026-05-19  0.035245 -0.943528

# %%
df.loc[dates[0],"A"]
# Out:
# np.float64(-0.16971222593567103)

# %%
df.at[dates[0],"A"]
# Out:
# np.float64(-0.16971222593567103)

# %%
print(df.iloc[3])
print(df.iloc[3:5,0:2])
print(df.iloc[[1,2,4],[0,2]])
print(df.iloc[1:3,:])
print(df.iloc[:,1:3])
print(df.iloc[1,1])
print(df.iat[1,1])
# Out:
# A   -1.343448
# B   -0.767639
# C   -1.501292
# D    0.832573
# Name: 2026-05-20 00:00:00, dtype: float64
#                    A         B
# 2026-05-20 -1.343448 -0.767639
# 2026-05-21  3.472495  0.354432
#                    A         C
# 2026-05-18 -1.006015 -1.739034
# 2026-05-19  0.035245 -0.436862
# 2026-05-21  3.472495  0.210545
#                    A         B         C         D
# 2026-05-18 -1.006015 -0.013800 -1.739034  0.081955
# 2026-05-19  0.035245 -0.943528 -0.436862 -1.182899
#                    B         C
# 2026-05-17 -0.414671 -1.146815
# 2026-05-18 -0.013800 -1.739034
# 2026-05-19 -0.943528 -0.436862
# 2026-05-20 -0.767639 -1.501292
# 2026-05-21  0.354432  0.210545
# 2026-05-22  1.307388 -1.345943
# -0.013800027781930091
# -0.013800027781930091

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2026-05-19  0.035245 -0.943528 -0.436862 -1.182899
# 2026-05-21  3.472495  0.354432  0.210545 -0.072325

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2026-05-17       NaN       NaN       NaN       NaN
# 2026-05-18       NaN       NaN       NaN  0.081955
# 2026-05-19  0.035245       NaN       NaN       NaN
# 2026-05-20       NaN       NaN       NaN  0.832573
# 2026-05-21  3.472495  0.354432  0.210545       NaN
# 2026-05-22       NaN  1.307388       NaN       NaN
