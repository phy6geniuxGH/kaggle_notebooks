# %%
import numpy as np
import pandas as pd

s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# datetime index
dates = pd.date_range("20260517", periods=6)
print(dates)

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
print(df)
# Out:
# DatetimeIndex(['2026-05-17', '2026-05-18', '2026-05-19', '2026-05-20',
#                '2026-05-21', '2026-05-22'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2026-05-17  0.798540  0.464983  1.713300 -1.090738
# 2026-05-18  0.994329 -3.172904 -0.516606  2.117485
# 2026-05-19  1.105393 -0.296100 -0.327189 -0.687277
# 2026-05-20 -0.044431  0.068880  1.412468  2.221935
# 2026-05-21 -1.022522 -0.939294 -0.958755  0.558191
# 2026-05-22 -0.029582  1.159218  0.751399 -1.339316
