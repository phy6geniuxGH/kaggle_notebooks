# %%
import numpy as np
import pandas as pd

s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# datetime index
dates = pd.date_range("20260517", periods=6)
print(dates)

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
print(df)
# Out:
# DatetimeIndex(['2026-05-17', '2026-05-18', '2026-05-19', '2026-05-20',
#                '2026-05-21', '2026-05-22'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2026-05-17 -1.552939 -1.879771  0.819503  0.449556
# 2026-05-18 -2.403247  0.296320  1.380499  1.409131
# 2026-05-19 -0.087088 -2.085657  0.923747  0.004219
# 2026-05-20  0.524602 -0.703652 -1.285106 -1.556615
# 2026-05-21 -0.442795 -0.901123  0.371998  0.650281
# 2026-05-22  0.175523 -0.347797 -0.280581 -1.272561

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
